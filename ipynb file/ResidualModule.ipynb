# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Input, Concatenate, Conv2D, MaxPooling2D, Add
from tensorflow.keras.models import Model

main_input = Input(shape=(28, 28, 256))
conv1164 = Conv2D(64, (1,1), padding='same') (main_input)
conv3364 = Conv2D(64, (3,3), padding='same') (conv1164)
conv11256 = Conv2D(256, (1,1), padding='same') (conv3364)

main_output = Add() ([main_input, conv11256])

# 모델 구성 (입력값들과 출력값들)
model = Model(inputs=[main_input], outputs=[main_output])
model.summary()

# 출력
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='model.jpg', show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_3 (InputLayer)        [(None, 28, 28, 256)]        0         []
#
#  conv2d_6 (Conv2D)           (None, 28, 28, 64)           16448     ['input_3[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 64)           36928     ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 256)          16640     ['conv2d_7[0][0]']
#
#  add_2 (Add)                 (None, 28, 28, 256)          0         ['input_3[0][0]',
#                                                                      'conv2d_8[0][0]']
#
# ...
# Total params: 70016 (273.50 KB)
# Trainable params: 70016 (273.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
