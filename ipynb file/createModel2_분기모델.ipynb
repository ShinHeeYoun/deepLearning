# %%
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model

input1 = Input(shape=(28*28,))
output1 = Dense(10, activation='sigmoid') (input1)
output2 = Dense(1 ,activation='softmax') (input1)
model = Model(inputs=[input1], outputs=[output1, output2])
model.summary()
plot_model(model, to_file='m.jpg', show_shapes=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 784)]                0         []
#
#  dense (Dense)               (None, 10)                   7850      ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    785       ['input_1[0][0]']
#
# ==================================================================================================
# Total params: 8635 (33.73 KB)
# Trainable params: 8635 (33.73 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
